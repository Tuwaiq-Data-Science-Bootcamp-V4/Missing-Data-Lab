# %% [markdown]
# ### Import your libraries

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load your dataset

# %%
df = pd.read_csv('HR_Missing_Values.csv')
df
# Out:
#                 Employee_Name  EmpID    Salary  PositionID  \
# 0         Adinolfi, Wilson  K  10026   62506.0          19
# 1    Ait Sidi, Karthikeyan     10084  104437.0          27
# 2           Akinkuolie, Sarah  10196   64955.0          20
# 3                Alagbe,Trina  10088   64991.0          19
# 4                         NaN  10069   50825.0          19
# ..                        ...    ...       ...         ...
# 306            Woodson, Jason  10135   65893.0          20
# 307        Ybarra, Catherine   10301   48513.0          19
# 308                       NaN  10010  220450.0           6
# 309               Zhou, Julia  10043   89292.0           9
# 310                       NaN  10271   45046.0          19
#
#                      Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 0     Production Technician I  07/10/83  M       Single    White   7/5/2011
# 1                     Sr. DBA  05/05/75  M      Married    White  3/30/2015
# ...

# %% [markdown]
# ### Explore your data
#
# * First 5 recods.
# * Last 5 records.
# * Check data types.
# * Show statistical summary.
# * Is there any missing values?
# * Applay two more data analysis from your choose.

# %%
df.head()
# Out:
#               Employee_Name  EmpID    Salary  PositionID  \
# 0       Adinolfi, Wilson  K  10026   62506.0          19
# 1  Ait Sidi, Karthikeyan     10084  104437.0          27
# 2         Akinkuolie, Sarah  10196   64955.0          20
# 3              Alagbe,Trina  10088   64991.0          19
# 4                       NaN  10069   50825.0          19
#
#                    Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 0   Production Technician I  07/10/83  M       Single    White   7/5/2011
# 1                   Sr. DBA  05/05/75  M      Married    White  3/30/2015
# 2  Production Technician II  09/19/88   F     Married    White   7/5/2011
# 3   Production Technician I       NaN   F     Married    White   1/7/2008
# 4   Production Technician I  09/08/89   F    Divorced    White  7/11/2011
#
#   DateofTermination         Department     ManagerName  ManagerID  \
# 0               NaN  Production         Michael Albert       22.0
# ...

# %%
df.tail()
# Out:
#           Employee_Name  EmpID    Salary  PositionID  \
# 306      Woodson, Jason  10135   65893.0          20
# 307  Ybarra, Catherine   10301   48513.0          19
# 308                 NaN  10010  220450.0           6
# 309         Zhou, Julia  10043   89292.0           9
# 310                 NaN  10271   45046.0          19
#
#                      Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 306  Production Technician II  05/11/85  M       Single    White   7/7/2014
# 307   Production Technician I       NaN   F      Single    Asian   9/2/2008
# 308                       CIO       NaN   F      Single    White  4/10/2010
# 309              Data Analyst  02/24/79   F      Single    White  3/30/2015
# 310   Production Technician I  08/17/78   F     Widowed    Asian  9/29/2014
#
#     DateofTermination         Department     ManagerName  ManagerID  \
# 306               NaN  Production         Kissy Sullivan       20.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_Name      218 non-null    object
#  1   EmpID              311 non-null    int64
#  2   Salary             249 non-null    float64
#  3   PositionID         311 non-null    int64
#  4   Position           311 non-null    object
#  5   DOB                280 non-null    object
#  6   Sex                249 non-null    object
#  7   MaritalDesc        311 non-null    object
#  8   RaceDesc           311 non-null    object
#  9   DateofHire         311 non-null    object
#  10  DateofTermination  104 non-null    object
#  11  Department         311 non-null    object
#  12  ManagerName        311 non-null    object
#  13  ManagerID          303 non-null    float64
#  14  RecruitmentSource  311 non-null    object
#  15  Absences           280 non-null    float64
# ...

# %%
df.describe()
# Out:
#               EmpID         Salary  PositionID   ManagerID    Absences
# count    311.000000     249.000000  311.000000  303.000000  280.000000
# mean   10156.000000   67972.662651   16.845659   14.570957   10.128571
# std       89.922189   22995.908395    6.223419    8.078306    5.946407
# min    10001.000000   45046.000000    1.000000    1.000000    1.000000
# 25%    10078.500000   55315.000000   18.000000   10.000000    4.750000
# 50%    10156.000000   62957.000000   19.000000   15.000000   10.000000
# 75%    10233.500000   71707.000000   20.000000   19.000000   15.250000
# max    10311.000000  220450.000000   30.000000   39.000000   20.000000

# %%
df.isnull().sum()
# Out:
# Employee_Name         93
# EmpID                  0
# Salary                62
# PositionID             0
# Position               0
# DOB                   31
# Sex                   62
# MaritalDesc            0
# RaceDesc               0
# DateofHire             0
# DateofTermination    207
# Department             0
# ManagerName            0
# ManagerID              8
# RecruitmentSource      0
# Absences              31
# dtype: int64

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'Salary', 'PositionID', 'Position', 'DOB',
#        'Sex', 'MaritalDesc', 'RaceDesc', 'DateofHire', 'DateofTermination',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'Absences'],
#       dtype='object')

# %%
df.shape
# Out:
# (311, 16)

# %% [markdown]
# ### Do the following steps for each column with missing values.
# * Identity the column.
# * How much precentage the missing value represents?
# * What is the best way to handle these missing values and why?
# * Apply your method to the column.

# %% [markdown]
# - ✅ Employee_Name
# - ✅ Salary
# - ✅ DOB
# - ✅ Sex
# - ✅ DateofTermination
# - ✅ ManagerID
# - ✅ Absences

# %% [markdown]
# #### Employee_Name Column:

# %%
df['Employee_Name'].isnull().sum()
# Out:
# 93

# %%
(df['Employee_Name'].isnull().sum()/311)*100
# Out:
# 29.903536977491964

# %%
df['Employee_Name'] = df['Employee_Name'].fillna(df['EmpID'])

# %%
df['Employee_Name'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Salary Column:

# %%
df['Salary'].isnull().sum()
# Out:
# 62

# %%
(df['Salary'].isnull().sum()/311)*100
# Out:
# 19.935691318327976

# %%
df[df['Salary'].isna()]
# Out:
#             Employee_Name  EmpID  Salary  PositionID                 Position  \
# 9                   10250  10250     NaN          14               IT Support
# 10   Baczenski, Rachael    10252     NaN          19  Production Technician I
# 19                  10277  10277     NaN          19  Production Technician I
# 20                  10046  10046     NaN          19  Production Technician I
# 22                  10003  10003     NaN          19  Production Technician I
# ..                    ...    ...     ...         ...                      ...
# 289      Veera, Abdellah   10014     NaN          19  Production Technician I
# 290         Vega, Vincent  10144     NaN          17       Production Manager
# 292       Voldemort, Lord  10118     NaN           8   Database Administrator
# 294  Von Massenbach, Anna  10183     NaN          19  Production Technician I
# 298                 10172  10172     NaN          22      Senior BI Developer
#
# ...

# %%
df.groupby(['Position','Sex'])['Salary'].mean()
# Out:
# Position                      Sex
# Accountant I                  F       63000.000000
#                               M       63761.500000
# Administrative Assistant      F       52280.000000
# Area Sales Manager            F       64190.125000
#                               M       64131.166667
# BI Developer                  F       95920.000000
#                               M       93460.000000
# CIO                           F      220450.000000
# Data Analyst                  F       89587.500000
#                               M       89199.750000
# Data Analyst                  M                NaN
# Data Architect                F                NaN
# Database Administrator        F      114800.000000
#                               M                NaN
# Director of Operations        M      170500.000000
# Enterprise Architect          M                NaN
# IT Director                   M      178000.000000
# IT Manager - DB               M                NaN
# ...

# %%
for i in range(len(df)):
    if df.isnull().iloc[i, 2] :
        df['Salary'][i] = df.groupby(['Position','Sex'])['Salary'].transform(lambda x: x.fillna(x.mean()))

# %%
df['Salary'].isnull().sum()
# Out:
# 17

# %%
for i in range(len(df)):
    if df.isnull().iloc[i, 2] :
        df['Salary'][i] = df['Salary'].mean()

# %%
df['Salary'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### DOB Column:

# %%
df['DOB'].isnull().sum()
# Out:
# 31

# %%
(df['DOB'].isnull().sum()/311)*100
# Out:
# 9.967845659163988

# %%
df[df['DOB'].isna()]
# Out:
#              Employee_Name  EmpID         Salary  PositionID  \
# 3             Alagbe,Trina  10088   64991.000000          19
# 42       Champaigne, Brian  10108  110929.000000           5
# 69                   10310  10310   53189.000000          19
# 84       Estremera, Miguel  10280   60340.000000          19
# 92         Fidelia,  Libby  10049   58530.000000          19
# 96                   10015  10015  178000.000000          12
# 97       Foster-Baker, Amy  10080   99351.000000          26
# 107         Givens, Myriam  10255   61555.000000           3
# 112         Gonzalez, Juan  10300   68898.000000          20
# 119                  10059  10059   63813.000000          19
# 127     Hendrickson, Trina  10075   68099.000000          20
# 139                  10227  10227   61242.000000          19
# 157            Landa, Hans  10092   82758.000000          18
# 160   LaRotonda, William    10038   64520.000000           1
# ...

# %%
df['DOB'] = df['DOB'].fillna(df['DOB'].mode()[0])

# %%
df['DOB'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Sex Column:

# %%
df['Sex'].isnull().sum()
# Out:
# 62

# %%
(df['Sex'].isnull().sum()/311)*100
# Out:
# 19.935691318327976

# %%
import re

# %%
df['Employee_Name'] = df['Employee_Name'].astype(str) 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_Name      311 non-null    object
#  1   EmpID              311 non-null    int64
#  2   Salary             311 non-null    float64
#  3   PositionID         311 non-null    int64
#  4   Position           311 non-null    object
#  5   DOB                311 non-null    object
#  6   Sex                249 non-null    object
#  7   MaritalDesc        311 non-null    object
#  8   RaceDesc           311 non-null    object
#  9   DateofHire         311 non-null    object
#  10  DateofTermination  104 non-null    object
#  11  Department         311 non-null    object
#  12  ManagerName        311 non-null    object
#  13  ManagerID          303 non-null    float64
#  14  RecruitmentSource  311 non-null    object
#  15  Absences           280 non-null    float64
# ...

# %%
for i in range(len(df)):
    df['Employee_Name'][i] = re.sub(",", " ", df['Employee_Name'][i])

# %%
df.loc[df['Employee_Name'].str.split().str.len() <= 3, 
       'Employee_First_Name'] = df['Employee_Name'].str.split().str[-1]
df
# Out:
#                 Employee_Name  EmpID    Salary  PositionID  \
# 0         Adinolfi  Wilson  K  10026   62506.0          19
# 1    Ait Sidi  Karthikeyan     10084  104437.0          27
# 2           Akinkuolie  Sarah  10196   64955.0          20
# 3                Alagbe Trina  10088   64991.0          19
# 4                       10069  10069   50825.0          19
# ..                        ...    ...       ...         ...
# 306            Woodson  Jason  10135   65893.0          20
# 307        Ybarra  Catherine   10301   48513.0          19
# 308                     10010  10010  220450.0           6
# 309               Zhou  Julia  10043   89292.0           9
# 310                     10271  10271   45046.0          19
#
#                      Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 0     Production Technician I  07/10/83  M       Single    White   7/5/2011
# 1                     Sr. DBA  05/05/75  M      Married    White  3/30/2015
# ...

# %%
import gender_guesser.detector as gender

# %%
df['gender'] = ''

# %%
for i in range(len(df)):
    df['gender'][i] = gender.Detector().get_gender(df['Employee_First_Name'][i])
df
# Out:
#                 Employee_Name  EmpID    Salary  PositionID  \
# 0         Adinolfi  Wilson  K  10026   62506.0          19
# 1    Ait Sidi  Karthikeyan     10084  104437.0          27
# 2           Akinkuolie  Sarah  10196   64955.0          20
# 3                Alagbe Trina  10088   64991.0          19
# 4                       10069  10069   50825.0          19
# ..                        ...    ...       ...         ...
# 306            Woodson  Jason  10135   65893.0          20
# 307        Ybarra  Catherine   10301   48513.0          19
# 308                     10010  10010  220450.0           6
# 309               Zhou  Julia  10043   89292.0           9
# 310                     10271  10271   45046.0          19
#
#                      Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 0     Production Technician I  07/10/83  M       Single    White   7/5/2011
# 1                     Sr. DBA  05/05/75  M      Married    White  3/30/2015
# ...

# %%
df[df['Sex'].isna()]
# Out:
#              Employee_Name  EmpID         Salary  PositionID  \
# 9                    10250  10250   66929.810447          14
# 15           Bates  Norman  10061   57834.000000          19
# 16        Beak  Kimberly    10023   70131.000000          20
# 18                   10245  10245  110000.000000           8
# 27          Bozzi  Charles  10175   74312.000000          18
# ..                     ...    ...            ...         ...
# 288        Valentin Jackie  10205   57859.000000           3
# 291       Villanueva  Noah  10253   55875.000000           3
# 293          Volk  Colleen  10022   49773.000000          19
# 300        Whittier  Scott  10072   58371.000000          19
# 303  Williams  Jacquelyn    10264   59728.000000          19
#
#                      Position       DOB  Sex MaritalDesc  \
# 9                  IT Support  01/07/88  NaN    Divorced
# 15    Production Technician I  10/18/81  NaN      Single
# 16   Production Technician II  04/17/66  NaN     Married
# ...

# %%
df['Sex'] = df['Sex'].astype(str) 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_Name        311 non-null    object
#  1   EmpID                311 non-null    int64
#  2   Salary               311 non-null    float64
#  3   PositionID           311 non-null    int64
#  4   Position             311 non-null    object
#  5   DOB                  311 non-null    object
#  6   Sex                  311 non-null    object
#  7   MaritalDesc          311 non-null    object
#  8   RaceDesc             311 non-null    object
#  9   DateofHire           311 non-null    object
#  10  DateofTermination    104 non-null    object
#  11  Department           311 non-null    object
#  12  ManagerName          311 non-null    object
#  13  ManagerID            303 non-null    float64
#  14  RecruitmentSource    311 non-null    object
# ...

# %%
for i in range(len(df)):
    if df['Sex'][i] == 'M':
        continue 
    elif df['gender'][i] == 'F':
        continue
    else: 
        if df['gender'][i] == 'male' :
            df['Sex'][i] = 'M'
        elif df['gender'][i] == 'mostly_male':
            df['Sex'][i] = 'M'
        elif df['gender'][i] == 'female':
            df['Sex'][i] = 'F'
        elif df['gender'][i] == 'mostly_female':
            df['Sex'][i] = 'F'
        else:
            continue   
df
# Out:
#                 Employee_Name  EmpID    Salary  PositionID  \
# 0         Adinolfi  Wilson  K  10026   62506.0          19
# 1    Ait Sidi  Karthikeyan     10084  104437.0          27
# 2           Akinkuolie  Sarah  10196   64955.0          20
# 3                Alagbe Trina  10088   64991.0          19
# 4                       10069  10069   50825.0          19
# ..                        ...    ...       ...         ...
# 306            Woodson  Jason  10135   65893.0          20
# 307        Ybarra  Catherine   10301   48513.0          19
# 308                     10010  10010  220450.0           6
# 309               Zhou  Julia  10043   89292.0           9
# 310                     10271  10271   45046.0          19
#
#                      Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 0     Production Technician I  07/10/83  M       Single    White   7/5/2011
# 1                     Sr. DBA  05/05/75  M      Married    White  3/30/2015
# ...

# %%
df['Sex'].isnull().sum()
# Out:
# 0

# %%
df['Sex'] = df['Sex'].str.strip()
df.Sex.unique()
# Out:
# array(['M', 'F', 'nan'], dtype=object)

# %%
for i in range(len(df)):
    if df['Sex'][i] == 'nan':
        df['Sex'][i] = df['Sex'].mode()[0]

# %%
df.Sex.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %% [markdown]
# #### DateofTermination Column:

# %%
df['DateofTermination'].isnull().sum()
# Out:
# 207

# %%
(df['DateofTermination'].isnull().sum()/311)*100
# Out:
# 66.55948553054662

# %%
df['DateofTermination'] = df['DateofTermination'].fillna('still working')

# %%
df['DateofTermination'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### ManagerID Column:

# %%
df['ManagerID'].isnull().sum()
# Out:
# 8

# %%
(df['ManagerID'].isnull().sum()/311)*100
# Out:
# 2.572347266881029

# %%
# Display all the null rows

df[df['ManagerID'].isna()]
# Out:
#           Employee_Name  EmpID        Salary  PositionID  \
# 19                10277  10277  53938.818182          19
# 30   Buccheri  Joseph    10184  65288.000000          20
# 44    Chang  Donovan  E  10154  66929.810447          19
# 88      Fancett  Nicole  10136  65902.000000          20
# 135               10214  10214  64995.000000          20
# 177   Manchester  Robyn  10077  62385.000000          20
# 232     Rivera  Haley    10011  46738.000000          19
# 251      Sewkumar  Nori  10071  50923.000000          19
#
#                      Position       DOB Sex MaritalDesc  \
# 19    Production Technician I  04/06/79   M      Single
# 30   Production Technician II  07/28/83   M      Single
# 44    Production Technician I  08/24/83   F      Single
# 88   Production Technician II  09/27/87   F      Single
# 135  Production Technician II  05/07/92   F   Separated
# 177  Production Technician II  08/25/76   F     Married
# ...

# %%
# Find the ManagerID by ManagerName

df.loc[df['ManagerName']=='Webster Butler']
# Out:
#              Employee_Name  EmpID        Salary  PositionID  \
# 4                    10069  10069  50825.000000          19
# 19                   10277  10277  53938.818182          19
# 30      Buccheri  Joseph    10184  65288.000000          20
# 44       Chang  Donovan  E  10154  66929.810447          19
# 65                   10070  10070  55722.000000          19
# 88         Fancett  Nicole  10136  65902.000000          20
# 89         Ferguson  Susan  10189  57748.000000          19
# 105                  10283  10283  54933.000000          19
# 124  Harrington  Christie   10097  52177.000000          19
# 135                  10214  10214  64995.000000          20
# 151   Kinsella  Kathleen    10166  54005.000000          19
# 174         Lynch  Lindsay  10004  47434.000000          19
# 177      Manchester  Robyn  10077  62385.000000          20
# 198         Ndzi  Colombui  10215  53938.818182          19
# 206        Oliver  Brooke   10078  71966.000000          20
# ...

# %%
# Fill all the null with the 39 which is the ManagerID

df['ManagerID'] = df['ManagerID'].fillna(39)

# %%
df.loc[df['ManagerName']=='Webster Butler']
# Out:
#              Employee_Name  EmpID        Salary  PositionID  \
# 4                    10069  10069  50825.000000          19
# 19                   10277  10277  53938.818182          19
# 30      Buccheri  Joseph    10184  65288.000000          20
# 44       Chang  Donovan  E  10154  66929.810447          19
# 65                   10070  10070  55722.000000          19
# 88         Fancett  Nicole  10136  65902.000000          20
# 89         Ferguson  Susan  10189  57748.000000          19
# 105                  10283  10283  54933.000000          19
# 124  Harrington  Christie   10097  52177.000000          19
# 135                  10214  10214  64995.000000          20
# 151   Kinsella  Kathleen    10166  54005.000000          19
# 174         Lynch  Lindsay  10004  47434.000000          19
# 177      Manchester  Robyn  10077  62385.000000          20
# 198         Ndzi  Colombui  10215  53938.818182          19
# 206        Oliver  Brooke   10078  71966.000000          20
# ...

# %%
df['ManagerID'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Absences Column:

# %%
df['Absences'].isnull().sum()
# Out:
# 31

# %%
(df['Absences'].isnull().sum()/311)*100
# Out:
# 9.967845659163988

# %%
df.Absences.unique()
# Out:
# array([ 1., 17.,  3., 15.,  2., 19.,  4., 16., 12.,  9.,  7., 20.,  8.,
#        nan, 13.,  5., 14.,  6., 11., 10., 18.])

# %%
# Since ther is no zeros I assum that nan means that there is no absences so null will be 0
df['Absences'] = df['Absences'].fillna(0)

# %%
df['Absences'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Is there any missing values left?

# %%
df.isnull().sum()
# Out:
# Employee_Name          0
# EmpID                  0
# Salary                 0
# PositionID             0
# Position               0
# DOB                    0
# Sex                    0
# MaritalDesc            0
# RaceDesc               0
# DateofHire             0
# DateofTermination      0
# Department             0
# ManagerName            0
# ManagerID              0
# RecruitmentSource      0
# Absences               0
# Employee_First_Name    0
# gender                 0
# dtype: int64
